# %%
print('\tessential items available\nS.NO \t\tItem\t\t Quantity\t Cost/Item\n1 \t\tBiscuit\t\t 5\t\t 20.50\n2 \t\tCereals\t\t 10\t\t 90.00\n3 \t\tChickens\t 20\t\t 200.00\n4 \t\tOats\t\t 20\t\t 39.99\n4 \t\tRice\t\t 30\t\t 79.99\n')
essential_items={1:{"Biscuit":{5:20.50}},
                    2:{"Cereals":{10:90.00}},3:{"Chickens":{20:200.00}},
                    4:{"Oats":{20:39.99}},5:{"Rice":{30:79.99}}}
while True:
    essential_items
    cost=[]
    qty=[]
    qty1=[]
    for i in essential_items:
        x=essential_items[i]
        for k,j in x.items():
            for k1,j1 in j.items():
                qty1.append(k1)
                while True:
                    print(f'how many {k} packets do you want: ')
                    y=int(input(f'type the quantity of {k} you want'))
                    if y<=k1:
                        z=y*j1
                        cost.append(z)
                        qty.append(y)
                        break
                    else:
                        print(f'please check the available quatity and try again!')
                        continue

    print('fill in the delivery details')
    print('please enter your name: ')
    name=input('please enter your name')
    print('please enter your address: ')
    address=input('please enter your address')

    while True:
        print('distance from store 5/10/15: ')
        distance=int(input('distance from store'))
        if distance<=5:
            x22=10
            break
        elif distance<=10 and distance>5:
            x22=20
            break
        elif distance<=15 and distance>10:
            x22=30
            break
        else:
            print('please enter in the range of available delivery distance')
            continue
        
    print('delivery charge : 30 will be levied for 15 km of distance')


    print(f'\n\n\n\tBILL\nS.NO \t\tItem\t\t Quantity\t Totalcost\n1 \t\tBiscuit\t\t {qty[0]}\t\t {cost[0]}\n2 \t\tCereals\t\t {qty[1]}\t\t {cost[1]}\n3 \t\tChickens\t {qty[2]}\t\t {cost[2]}\n4 \t\tOats\t\t {qty[3]}\t\t {cost[3]}\n4 \t\tRice\t\t {qty[4]}\t\t {cost[4]}\n')
    print(f'total items cost : {sum(cost)}')
    print(f'Total bill amount =total item cost +delivery charges:{sum(cost) +x22} ')
    print(f'name: {name}')
    print(f'address: {address}')
    print(f'do you want to continue :y/n ')
    x=input('do you want to continue :y/n')
    if x=='y':
        essential_items[1]['Biscuit']={qty1[0]-qty[0]:20.5}
        essential_items[2]['Cereals']={qty1[1]-qty[1]:190.00}
        essential_items[3]['Chickens']={qty1[2]-qty[2]:200.00}
        essential_items[4]['Oats']={qty1[3]-qty[3]:39.99}
        essential_items[5]['Rice']={qty1[4]-qty[4]:79.99}
        print(f'\tessential items available\nS.NO \t\tItem\t\t Quantity\t Cost/Item\n1 \t\tBiscuit\t\t {qty1[0]-qty[0]}\t\t 20.50\n2 \t\tCereals\t\t {qty1[1]-qty[1]}\t\t 90.00\n3 \t\tChickens\t {qty1[2]-qty[2]}\t\t 200.00\n4 \t\tOats\t\t {qty1[3]-qty[3]}\t\t 39.99\n4 \t\tRice\t\t {qty1[4]-qty[4]}\t\t 79.99\n')
        if qty1[0]-qty[0]==0 and qty1[1]-qty[1]==0 and qty1[2]-qty[2]==0 and qty1[3]-qty[3]==0 and qty1[4]-qty[4]==0:
            print ('out of stock! please visit later')
            break
        else:
            continue
    elif x=='n':
        print('Thank you for shopping with us')
        break
# Out:
# 	essential items available
# S.NO 		Item		 Quantity	 Cost/Item
# 1 		Biscuit		 5		 20.50
# 2 		Cereals		 10		 90.00
# 3 		Chickens	 20		 200.00
# 4 		Oats		 20		 39.99
# 4 		Rice		 30		 79.99
#
# how many Biscuit packets do you want:
# how many Cereals packets do you want:
# how many Chickens packets do you want:
# how many Oats packets do you want:
# how many Rice packets do you want:
# fill in the delivery details
# please enter your name:
# please enter your address:
# distance from store 5/10/15:
# delivery charge : 30 will be levied for 15 km of distance
#
#
#
# 	BILL
# S.NO 		Item		 Quantity	 Totalcost
# 1 		Biscuit		 1		 20.5
# 2 		Cereals		 2		 180.0
# 3 		Chickens	 6		 1200.0
# 4 		Oats		 2		 79.98
# 4 		Rice		 1		 79.99
#
# total items cost : 1560.47
# Total bill amount =total item cost +delivery charges:1580.47
# name: Rishabh
# address: asdhnaskjdhaksjdljf
# do you want to continue :y/n
# Thank you for shopping with us
